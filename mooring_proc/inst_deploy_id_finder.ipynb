# %% [markdown]
# # inst_deploy_ID finder
#
# Use this notebook to find deployment IDs before running any pipeline notebook.
#
# Workflow:
# 1. Run Imports.
# 2. Set finder filters (leave as None to skip).
# 3. Run the preview cell to print and display matching rows.
# 4. Copy the `inst_deploy_ID` you want into the pipeline notebook setup cell.

# %%
import sys
from pathlib import Path

try:
    from IPython.display import display
except ModuleNotFoundError:
    def display(value):
        print(value)

NOTEBOOK_DIR = Path.cwd().resolve()
if not (NOTEBOOK_DIR / 'tools').exists() and (NOTEBOOK_DIR / 'mooring_proc' / 'tools').exists():
    sys.path.insert(0, str((NOTEBOOK_DIR / 'mooring_proc').resolve()))

from tools.inst_deploy_id_finder import preview_inst_deploy_ids

# %%
instrument = "SBE37"
year = 2025
location = "BASJAS"
mooring_channel = None
deployment_id = None
search_text = None
max_rows = 25

# %%
results = preview_inst_deploy_ids(
    instrument=instrument,
    year=year,
    location=location,
    mooring_channel=mooring_channel,
    deployment_id=deployment_id,
    search_text=search_text,
    max_rows=max_rows,
)
# Out:
# Matched 4 row(s).
#  inst_deploy_ID deployment_id location inst_type  inst_id mooring_channels time_coverage_start   time_coverage_end
#             266         2025c   BASJAS     SBE37    20372           PTSUVW 2025-02-07T03:32:00 2026-03-04T02:17:00
#             275         2025f   BASJAS     SBE37     9335            PTSUV 2025-08-23T06:00:00 2026-08-26T21:10:00
#             277         2025f   BASJAS     SBE37    20374            PTSUV 2025-08-23T06:00:00 2026-08-26T21:10:00
#             278         2025f   BASJAS     SBE37     9336            PTSUV 2025-08-23T06:00:00 2026-08-26T21:10:00

# %%
# Interactive table
display(results)
# Out:
#    inst_deploy_ID  bl_id bl_channels location deployment_id mooring_channels  \
# 0             266    NaN         TCS   BASJAS         2025c           PTSUVW
# 1             275    NaN         NaN   BASJAS         2025f            PTSUV
# 2             277    NaN         NaN   BASJAS         2025f            PTSUV
# 3             278    NaN         NaN   BASJAS         2025f            PTSUV
#
#    longitude  latitude  nominal_depth inst_type  ...    time_coverage_end  \
# 0  145.58685  -40.6366           50.0     SBE37  ...  2026-03-04T02:17:00
# 1  145.59100  -40.6410           52.0     SBE37  ...  2026-08-26T21:10:00
# 2  145.59100  -40.6410           52.0     SBE37  ...  2026-08-26T21:10:00
# 3  145.59100  -40.6410           52.0     SBE37  ...  2026-08-26T21:10:00
#
#          recovery_date  mag_dec time_offset (PC-inst, sec)  \
# 0  2026-03-04T02:15:00      NaN                        NaN
# 1  2026-08-26T21:50:00      NaN                        NaN
# 2  2026-08-26T21:50:00      NaN                        NaN
# 3  2026-08-26T21:50:00      NaN                        NaN
#
#                              data_in_file  \
# 0  SBE37SMP-RS232_03720372_2026_03_11.cnv
# 1   SBE37SM-RS232_03709335_2026_08_30.cnv
# 2                                     NaN
# 3                                     NaN
#
#                                          proc_1_file  \
# 0                                                NaN
# 1  IMOS_SRSALT_TCS_20250823T060000Z_BASJAS_FV00_S...
# 2                                                NaN
# 3                    BASJAS_202508_SBE37_9336_52m.nc
#
#                        proc_2_file  \
# 0                              NaN
# 1  BASJAS_202508_SBE37_9335_52m.nc
# 2                              NaN
# 3                              NaN
#
#                               imos_deliverables_file  version comment
# 0                                                NaN      1.0     NaN
# 1  IMOS_SRSALT_PTSUV_20250823T060000Z_BASJAS_FV00...      NaN     NaN
# 2                                                NaN      NaN     NaN
# 3                                                NaN      NaN     NaN
#
# [4 rows x 25 columns]
